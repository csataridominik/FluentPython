# %%
import collections

Card = collections.namedtuple('Cards', ['rank', 'suit'])

class FrenchDeck:
    ranks = [str(n) for n in range(2,11)] + list('JQKA')
    suits = 'spades diamonds clubs hearts'.split()

    def __init__(self):
        self._cards = [Card(rank,suit) for suit in self.suits
                                       for rank in self.ranks]

    def __len__(self):
        return len(self._cards)
    
    def __getitem__(self,position):
        return self._cards[position]

# %%
beer_card = Card('7', 'diamonds')
beer_card
# Out:
# Cards(rank='7', suit='diamonds')

# %%
deck = FrenchDeck()
len(deck)
deck[-1]
# Out:
# Cards(rank='A', suit='hearts')

# %%
from random import choice

choice(deck)
# Out:
# Cards(rank='7', suit='clubs')

# %%
deck._cards
# Out:
# [Cards(rank='2', suit='spades'),
#  Cards(rank='3', suit='spades'),
#  Cards(rank='4', suit='spades'),
#  Cards(rank='5', suit='spades'),
#  Cards(rank='6', suit='spades'),
#  Cards(rank='7', suit='spades'),
#  Cards(rank='8', suit='spades'),
#  Cards(rank='9', suit='spades'),
#  Cards(rank='10', suit='spades'),
#  Cards(rank='J', suit='spades'),
#  Cards(rank='Q', suit='spades'),
#  Cards(rank='K', suit='spades'),
#  Cards(rank='A', suit='spades'),
#  Cards(rank='2', suit='diamonds'),
#  Cards(rank='3', suit='diamonds'),
#  Cards(rank='4', suit='diamonds'),
#  Cards(rank='5', suit='diamonds'),
#  Cards(rank='6', suit='diamonds'),
#  Cards(rank='7', suit='diamonds'),
#  Cards(rank='8', suit='diamonds'),
#  Cards(rank='9', suit='diamonds'),
#  Cards(rank='10', suit='diamonds'),
#  Cards(rank='J', suit='diamonds'),
#  Cards(rank='Q', suit='diamonds'),
#  Cards(rank='K', suit='diamonds'),
#  Cards(rank='A', suit='diamonds'),
#  Cards(rank='2', suit='clubs'),
#  Cards(rank='3', suit='clubs'),
#  Cards(rank='4', suit='clubs'),
#  Cards(rank='5', suit='clubs'),
#  Cards(rank='6', suit='clubs'),
#  Cards(rank='7', suit='clubs'),
#  Cards(rank='8', suit='clubs'),
#  Cards(rank='9', suit='clubs'),
#  Cards(rank='10', suit='clubs'),
#  Cards(rank='J', suit='clubs'),
#  Cards(rank='Q', suit='clubs'),
#  Cards(rank='K', suit='clubs'),
#  Cards(rank='A', suit='clubs'),
#  Cards(rank='2', suit='hearts'),
#  Cards(rank='3', suit='hearts'),
#  Cards(rank='4', suit='hearts'),
#  Cards(rank='5', suit='hearts'),
#  Cards(rank='6', suit='hearts'),
#  Cards(rank='7', suit='hearts'),
#  Cards(rank='8', suit='hearts'),
#  Cards(rank='9', suit='hearts'),
#  Cards(rank='10', suit='hearts'),
#  Cards(rank='J', suit='hearts'),
#  Cards(rank='Q', suit='hearts'),
#  Cards(rank='K', suit='hearts'),
#  Cards(rank='A', suit='hearts')]

# %%
Card(rank='A', suit='hearts') in deck
# Out:
# True

# %%
import math

class Vector:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    
    def __add__(self,other):
        return Vector(self.x+other.x,self.y+other.y)

    def __abs__(self):
        return math.sqrt(self.x**2 + self.y**2)
    
    def __str__(self):
        return f'x: {self.x} | y: {self.y}'

    def __repr__(self):
        return f'Vector({self.x!r}, {self.y!r})'

    def __mul__(self,mul):
        return Vector(self.x*mul,self.y*mul)

# %%
v1 = Vector(0,1)
v2 = Vector(1,0)
v3 = v1+v2
print(v3)
v3
# Out:
# x: 1 | y: 1
# Vector(1!r, 1!r)

# %%
v3*2
# Out:
# Vector(x=2, y=2)

# %%
abs(Vector(3,4))
# Out:
# 5.0
